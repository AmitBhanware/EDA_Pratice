# %% [markdown]
# Python OOP's - Inheritance

# %%
class Car:
   def __init__(self,windows, doors, enginetype):
    self.windows = window
    self.doors = door
    self.enginetype = enginetype

   def drive(self):
    print('The Person drive the car')

# %%
car = Car(4,5,'diesel')

# %%
#dir(Car)

# %%
car.drive()
# Out:
# The Person drive the car

# %%
class audi(Car):
  def __init__(self, windows, doors, enginetype, enableai):
    super().__init__(windows, doors, enginetype)
    self.ehableai = enableai
  def selfriving(self):
    print('Audi support self driving')

# %%
audiQ7 = audi(5,5,'diesel', True)

# %%
c = Car(4,5,'diesel')

# %%
#dir(c)

# %% [markdown]
# Magic Method in OOPs

# %%
class Car:
   def __new__(self,windows, doors, enginetype):
    print('the object has get initialized')

   def __init__(self,windows, doors, enginetype):
    self.windows = window
    self.doors = door
    self.enginetype = enginetype
   def __sizeof__(self):
    return 'This diplay size of object'

   def drive(self):
    print('The Person drive the car')

# %%
num = 10
assert num > 10
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_7286/2508948752.py in <cell line: 0>()
#       1 num = 10
# ----> 2 assert num > 10
#
# AssertionError:

# %%
try:
  num = int(input('Enter the number'))
  assert num%2 == 0
  print('The number is even ')
except AssertionError:
  print('Enter the even number ')
# Out:
# Enter the number3
# Enter the even number

# %%
lst = [1,2,3,4,5]

# %%
iterable = iter(lst)

# %%
for i in iterable:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
next(iterable)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_39601/1608679135.py in <cell line: 0>()
# ----> 1 next(iterable)
#
# StopIteration:

# %%
try:
  next(iterable)
except StopIteration :
  print('The iterator is empty')
# Out:
# The iterator is empty

# %%
#Generator

def square(n):
  for i in range(n):
    yield n**2

# %%
a = square(3)

# %%
next(a)
# Out:
# 9

# %% [markdown]
# Decorators

# %%
# function  copy
# clousers
# decorators

# %%
def welcome() :
  print('Welcome to Learnig')

# %%
wel = welcome()
del welcome
# Out:
# Welcome to Learnig

# %%
welcome()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2907/241228648.py in <cell line: 0>()
# ----> 1 welcome()
#
# NameError: name 'welcome' is not defined

# %%
#clousers
def main_welcome(msg):

  def sub_welcome_class():
    print('Welcome to learning')
    print('msg')
  return sub_welcome_class()

# %%
main_welcome('Amit')
# Out:
# Welcome to learning
# msg
