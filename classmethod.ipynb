# %%
class car:
  base_price = 1000000
  def __init__(self,windows, doors, power):
    self.windows = windows
    self.doors = doors
    self.power = power

  def what_base_price(self):
    print('The base price is {}'.format(self.base_price))
  @classmethod
  def revise_baseprice(cls, inflation):
    cls.base_price = cls.base_price + cls.base_price*inflation

# %%
car.revise_baseprice(0.10)

# %%
car1 = car(4,5,2000)

# %%
car1.base_price
# Out:
# 1100000.0

# %%
car.revise_baseprice(0.10)

# %%
car3 = car(5,6,4000)

# %%
car3.base_price
# Out:
# 1210000.0

# %%
car1.base_price
# Out:
# 1331000.0

# %%
import datetime
now = datetime.datetime.now()

# %%
class car:
  base_price = 1000000
  def __init__(self,windows, doors, power):
    self.windows = windows
    self.doors = doors
    self.power = power

  def what_base_price(self):
    print('The base price is {}'.format(self.base_price))
  @classmethod
  def revise_baseprice(cls, inflation):
    cls.base_price = cls.base_price + cls.base_price*inflation

  @staticmethod
  def check_year(year):
    if now.year == 2026:
      return True
    else:
      return False

# %%
car.check_year(now)
# Out:
# True

# %%
car1 = car(4,5,2000)

# %%
car1.check_year(now)
# Out:
# True

# %%
if (car1.check_year(now)):
  pass
else:
  car1.revise_baseprice()

# %%
car1.base_price
# Out:
# 1000000
